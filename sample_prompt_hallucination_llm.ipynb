# %% [markdown]
# # sample whisper promptping

# %%
# !pip install git+https://github.com/Hasan-Naseer/whisperX.git@release/latest-faster-whisper-version
# Out:
# ...
#   Cloning https://github.com/Hasan-Naseer/whisperX.git (to revision release/latest-faster-whisper-version) to /tmp/pip-req-build-53wo6t8m
#   Running command git clone --filter=blob:none --quiet https://github.com/Hasan-Naseer/whisperX.git /tmp/pip-req-build-53wo6t8m
#   Running command git checkout -b release/latest-faster-whisper-version --track origin/release/latest-faster-whisper-version
#   Switched to a new branch 'release/latest-faster-whisper-version'
#   Branch 'release/latest-faster-whisper-version' set up to track remote branch 'release/latest-faster-whisper-version' from 'origin'.
#   Resolved https://github.com/Hasan-Naseer/whisperX.git to commit 28e59141a8a1c336feef2b44b9dfb958a55f2bba
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 4.6 MB/s eta 0:00:00
# ...

# %%
# !apt-get install libcudnn8 libcudnn8-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   libcudnn8 libcudnn8-dev
# 0 upgraded, 2 newly installed, 0 to remove and 38 not upgraded.
# Need to get 885 MB of archives.
# After this operation, 2,380 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcudnn8 8.9.7.29-1+cuda12.2 [444 MB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcudnn8-dev 8.9.7.29-1+cuda12.2 [440 MB]
# Fetched 885 MB in 24s (37.6 MB/s)
# Selecting previously unselected package libcudnn8.
# (Reading database ... 126455 files and directories currently installed.)
# Preparing to unpack .../libcudnn8_8.9.7.29-1+cuda12.2_amd64.deb ...
# Unpacking libcudnn8 (8.9.7.29-1+cuda12.2) ...
# Selecting previously unselected package libcudnn8-dev.
# ...

# %%
from huggingface_hub.utils import _runtime
_runtime._is_google_colab = False

# %%
# !pip install ctranslate2==4.4.0

# %%
import whisperx
import gc

device = "cuda"
audio_file = "/content/drive/MyDrive/REDC/Test/fn000049_1_003.wav"
batch_size = 8 # reduce if low on GPU mem
compute_type = "float16" # change to "int8" if low on GPU mem (may reduce accuracy)

# 1. Transcribe with original whisper (batched)
#model = whisperx.load_model("large-v2", device, compute_type=compute_type,initial_prompt='dat da dat')

# save model to local path (optional)
# model_dir = "/path/"
# model = whisperx.load_model("large-v2", device, compute_type=compute_type, download_root=model_dir)
# Out:
# /usr/local/lib/python3.12/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   torchaudio.set_audio_backend("soundfile")
# /usr/local/lib/python3.12/dist-packages/torchaudio/_internal/module_utils.py:71: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   return func(*args, **kwargs)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ...

# %%
import whisperx
model = whisperx.load_model("large-v3", device, language='nl',compute_type=compute_type, asr_options={"hotwords":None,"initial_prompt": "eerst ee rst eer st ehij geeft ze allemaal een naam eerste was hhij geeft ze allema ehij geeft ze allemaal een naamt et p lagened plad gen flagen plagen dat vond maar tje maar maarte maart t maartje wel leuk maar l eu k loek luk maar naar maar toen het pesten pe te sten werd is ze mevrouw fre f r e d d e r fre dder fledder vledder gaan hel pen h e l p e n gaan helpen hand gebaren handgebaren"})
audio_file = "/content/drive/MyDrive/REDC/Trim_Jasmin_Testing_Audio/fn000503/1.wav"
audio = whisperx.load_audio(audio_file)
result = model.transcribe(audio=audio,batch_size=batch_size)
print(result["segments"]) # before alignment

#print(result) # before alignment

# %%
result = model.transcribe(audio=audio,batch_size=batch_size)
print(text_norm_all(result["segments"])) # before alignment

# %% [markdown]
# # normalization

# %%
import pandas as pd
import os
import numpy as np
import json

Reformat_path = "/content/drive/MyDrive/REDC/Jasmin_Child_Reformat_SanneAnno/"
children_data_path = "/content/drive/MyDrive/REDC/JASMIN_textgrid/"
child_speaker_file = os.path.join(children_data_path+"sprekers_informatie.xlsx")
child_data = pd.read_excel(child_speaker_file, index_col=0, usecols = np.arange(0,11))

#long word can lead to index error in word_transcripiton



DUTCH_NORMALIZATION = {
    "okee": "ok", "oke": "ok", "okey": "ok", "OKEE": "ok", "OKE": "ok",
    "OKEY": "ok", "MIJN": "mijn", "mn": "mijn", "m'n": "mijn", "M'N": "mijn", "mjn": "mijn",
    "'t": "het", "'T": "het", "'n": "een", "Een": "een", "EEN": "een", "z'n": "zijn", "zn": "z'n",
    "'m":"hem",
    "d'r": "daar", "dr": "daar",
    "'s": "s", "zo'n": "zoon",
    "'k": "ik", "'K": "ik",
    "uh": "", "ggg":"","mmm":"",
    "s nachts": "s'nachts",
}

def normalize_Dutch_string(input_string):
    normalized_string = input_string
    for key, value in DUTCH_NORMALIZATION.items():
        normalized_string = normalized_string.replace(key, value)
    return normalized_string

def normalize_long_words(input_string):
    normalized_string = input_string
    for key, value in Long_word.items():
        normalized_string = normalized_string.replace(key, value)
    return normalized_string

def read_phone_file(filename):
    phone = []
    with open(filename, 'r') as file:
        for line in file:
            # Split each line into key and value
            phone.append(line.strip())

    return " ".join(phone)

def reverse(input_string):
    txt = input_string.split(" ") [::-1]
    return " ".join(txt)

def text_norm_all(s):
    # Convert to lowercase
    s = s.lower()

    # Replace tag_a words
    #s = s.replace("<tag_a>", "<unk>")  # Assuming <tag_a> is the tag to be replaced
    s = s.replace("*n", "")  # Remove *a
    s = s.replace("*a", "")  # Remove *a
    s = s.replace("*u", "")  # Remove *a
    s = s.replace("*s", "")  # Remove *a
    s = s.replace("*v", "")  # Remove *

    # Remove punctuation
    punctuation = ".?!,-"
    for p in punctuation:
        s = s.replace(p, "")

    s = s.replace("’", "'")




    s =  normalize_Dutch_string(s)


    return s

# %%
#Hallucination check example
children_data_path = "/content/drive/MyDrive/REDC/JASMIN_textgrid/"
child_speaker_file = os.path.join(children_data_path+"sprekers_informatie.xlsx")
child_data = pd.read_excel(child_speaker_file, index_col=0, usecols = np.arange(0,11))
transcription_irre={}

for i in range(0,len(child_data)):

  audio_file = "/content/drive/MyDrive/REDC/Trim_Jasmin_Audio/"+child_data.index[i]+".wav"
  audio = whisperx.load_audio(audio_file)
  result = model_irre.transcribe(audio=audio,batch_size=batch_size)
  temp=''.join([i['text'] for i in result["segments"]])

  level=child_data.Niveau.tolist()
  key=level[i].replace("-", "")
  readtxt=Prompt[key]
  transcription_irre[child_data.index[i]]=temp

  if 1.0*len(temp)>1.2*len(readtxt):
    print(child_data.index[i])
    transcription_irre[child_data.index[i]]=transcription_baseline[child_data.index[i]]


#1m49s

# %%
#prompt category

Prompt = {
,
    'AVI7': Error+"Soms waren het nomaden. Ze moesten hun kamp steeds verplaatsen. De vader, de grootvaders en de ooms vertelden de kleine jongen alles over de jacht en de oorlog."+"Indianen, bergen, woestijn, nomaden, vaste, bizons, lezen, schrijven, krijger, meisje, leren, grootvaders, ooms, jacht, oorlog, spoor, boog, huishouden, fruit, plukken, hout, broertjes, zusjes, taak, zorgen, moeder, rol, klas, school, geboren"
,
    'AVI8': Error+  "Sommige geleerden denken dat de maan van de aarde is losgerukt. Het is in elk geval wel zo dat de maan in de buurt van de aarde is ontstaan. Wanneer je ’s avonds naar de maan kijkt, lijkt het net of je een gezicht kunt zien."+"maan, miljard, ontstaan, geleerden, losgerukt, zeker, voorbeeld, stoffen, voorkomen, s avonds, gezicht, vlekken, kraters, plekken, ruimte, zwevende, brokken, ingeslagen, ruimtevaarders, ruimtepakken, ademen, beschermen, fel, schijnen, lucht, wolk, graden, warm, aarde, planeten"
,
    'AVI9': Error+ "Opa vertelde me dat er veel soorten duiven bestaan. De duiven droegen dan kleine berichtjes met zich mee in een kokertje aan hun poot. Nu zorgt de postbode dat je brief in de juiste bus terechtkomt." + "opa, twintig, duiven, naam, hok, tuin, granen, zaden, peulvruchten, energie, temperatuur, lichaam, afstand, terugvindt, kompas, landkaart, berichtjes, kokertje, postbode, Nederland, België, postduivenvereniging, duivenmelkers, meedoen, wedstrijden, afleggen, zaden, bijzonder, vervoeren, poot, dag"

}

# %% [markdown]
# # llm

# %%
#LLM: notes the gpt-4o-mini accessed at that moment is not available, the new-align needs to be re-adjusted
#the output may be not fit into extract_after_last_final_alignment anymore, this function may also need re-adjusted

# %%
#you need your own key
import os
from openai import OpenAI
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY", ""))

# %%
import json
#this is from sclite alignment file
def get_report_alignemnt(report_path):
  with open(report_path, 'r') as file:
    report_alignment = json.load(file)
  return report_alignment

# %%
def get_completion(prompt, model="gpt-4o-mini"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content

# %%
def new_hy_align(w2v2tr, whispertr):
    prompt = f"""
    I have a speech recording where a speaker reads a given text. The speaker may make reading errors such as insertions, deletions, and substitutions.

    I want to generate an improved transcription hypothesis alignment by leveraging two alignments:
    - **Whisper hypothesis alignment**: Formed by force-aligning the reference reading text with the Whisper transcription.
    - **Wav2Vec2 hypothesis alignment**: Formed by force-aligning the same reference reading text with the Wav2Vec2 transcription.

    ### Key Considerations
    - Whisper is generally more reliable for correctly transcribed words.
    - Wav2Vec2 is better at detecting clusters of insertion errors.
    - Both alignments provide word-by-word mappings between the reference reading text and the transcribed hypothesis. Each word alignment block contains:
      - `'ref'`: The  referenceword in the reference reading text.
      - `'hyp'`: The corresponding predicted word by the model.
      - `'eval_label'`: The error classification:
        - `'C'`: Correct
        - `'S'`: Substitution error
        - `'D'`: Deletion error
        - `'I'`: Insertion error

    ### Goal
    Your task is to create the new hypothesis alignment based on the provided whisper and wav2vec2 alignments
    Perform the following actions step-by-step to identify and correct errors in Whisper alignment.
    1. **Identify clusters of insertions**: In the wav2vec2 alignment, look for clusters of at least two continious insertions (I) that are not detected or partially detected in the whisper alignment.
    2. **Identify substitutions**: In the whisper alignment, check for substitutions (S) of the whisper alignment and determine if they should be kept or reverted by if they also existed in wav2vev2 alignment. Do not add/check substitutions in the wav2vevc2 alignment to the new alignment. If wav2vec2 alignment also detect a substitution then keep the error in whisper, otherwise, revert it to reference word.
    3. **Handle continuous error pairs**: In the whisper alignment, look for continuous insertion and substitution pairs (IS or SI) in the whisper alignment and determine if they can be merged or split based on their phonemic/sound similarity to the reference words.
    4. **if you remove any correct words in the Whisper alignment, if so, add them back. Construct the new hypothesis alignment** based on the whisper alignment, making the necessary modifications while keeping the correct (C) entries unchanged
    5. Recheck in the new alignment if you remove any correct (C) entries in the original Whisper alignment, if so, add them back
    ### Input Alignments, store them seperately
    **Wav2Vec2 Hypothesis Alignment:**
    {w2v2tr}

    **Whisper Hypothesis Alignment:**
    {whispertr}

    ### Output Format
    - Provide your final hypothesis alignment in lowercase without any special characters.
    - Begin your response with **'Final hypothesis alignment:'**.


    """
    response = get_completion(prompt)
    return response

# %%
raw_response={}
selected_items = []
for speaker in child_data.index:
  utter_id='(spk'+str(speaker)+'-utt01)'
  speaker_id='spk'+str(speaker)
  speaker_whisper_alignment = whisperalign_total['speakers'][speaker_id][utter_id]['words']
  speaker_w2v2_alignment = w2v2align_total['speakers'][speaker_id][utter_id]['words']
  import os
  from openai import OpenAI
  print(speaker)
  client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY", "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"))
  response= new_hy_align(speaker_w2v2_alignment,speaker_whisper_alignment)
  raw_response[speaker]=response

# %%
import re
import ast
def extract_after_last_final_alignment(text):
    text=text.replace('\n','')
    cleaned_text = re.sub(r'//[^,\]]*', '', text).strip()
    matches = list(re.finditer(r'Final hypothesis alignment:(.*?\}\])', text,re.DOTALL))
    if matches:
        last_match = matches[-1]
        text =  matches[-1].group(1)

    text=text.replace('`','')
    text=text.replace('\n','')
    text=text.replace('json','')
    text = re.sub(r'#.*', '', text).strip()
    pattern = r"\{'eval_label':.*?\}"

    # Find all matches
    matches = re.findall(pattern, text)

    # Convert matched strings to actual dictionaries using `ast.literal_eval()`
    dict_list = [ast.literal_eval(match) for match in matches]


    return ' '.join(item['hyp'] for item in dict_list)

#text = "[{'eval_label': 'C', 'ref': 'de', 'hyp': 'de'}, {'eval_label': 'C', 'ref': 'maan', 'hyp': 'maan'}##this is chaged, {'eval_label': 'C', 'ref': 'de', 'hyp': 'de'} ]"
hyp_string = extract_after_last_final_alignment(raw_response['fn000049'])
print(hyp_string)
